# %%
# !conda install -c conda-forge jpype1 -y

# %%
# !pip install pandas tabula
# !pip install pdfplumber==0.11.5

# %%
import pandas as pd
from tabula.io import read_pdf

import os
os.environ["CRYPTOGRAPHY_OPENSSL_NO_LEGACY"] = "1"
import pdfplumber

# %%
# preparar seleção do arquivo
arquivo_diretorio = "../output/download"
arquivo_nome = "Anexo_I_Rol_2021RN_465.2021_RN627L.2024.pdf"
arquivo = arquivo_diretorio + "/" + arquivo_nome

# saida csv
output_diretorio = "../output/csv"
output_nome = "dados_normalizados.csv"
#output = output_diretorio + "/" + output_nome
output = output_nome # para testes

# %%
def ler_legenda(arquivo_legenda, chaves):
    legenda_dict = {}

    with pdfplumber.open(arquivo_legenda) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if "Legenda:" in text:
                legenda_texto = text.split("Legenda:")[-1]
                linhas = legenda_texto.split("\n")

                for linha in linhas:
                    for chave in chaves:
                        if linha.startswith(chave + ":"):
                            legenda_dict[chave] = linha.split(":", 1)[1].strip()

    return legenda_dict

# %%
# remove quebra de linha e substitui as abreviações pelas legendas
def normalizar_tabela(df, legenda_abreviacoes):
    df.columns = [col.replace("\r", " ").replace("\n", " ") for col in df.columns]

    for col in df.columns:
        df[col] = df[col].astype(str).str.replace("\r", " ").str.replace("\n", " ")

        for chave, significado in legenda_abreviacoes.items():
            df[col] = df[col].replace(chave, significado)

    return df

# %%
# pegar as legendas
chaves_legenda = ["OD", "AMB"]
legenda = ler_legenda(arquivo, chaves_legenda)

# total de páginas
with pdfplumber.open(arquivo) as pdf:
    total_paginas = len(pdf.pages)
    print(total_paginas)

# preparar as leituras para não ficar escrevendo os cabeçalhos
primeira_pagina = True
pagina = 1

while pagina <= total_paginas:
    df_list = read_pdf(arquivo, pages=str(pagina), multiple_tables=True, lattice=True)

    if not df_list:
        pagina += 1
        continue

    df = df_list[0]
    print("normalizacao da pagina: ", pagina)

    df = normalizar_tabela(df, legenda)

    if not df.empty:
        df.to_csv(output, mode="a", index=False, encoding="utf-8", header=primeira_pagina)
        if primeira_pagina:
            primeira_pagina = False

    pagina += 1

print(f"Dados salvos em {output}!")
# Out:
# 181
# normalizacao da pagina:  1
# normalizacao da pagina:  2
# normalizacao da pagina:  3
# normalizacao da pagina:  4
# normalizacao da pagina:  5
# normalizacao da pagina:  6
# normalizacao da pagina:  7
# normalizacao da pagina:  8
# normalizacao da pagina:  9
# normalizacao da pagina:  10
# normalizacao da pagina:  11
# normalizacao da pagina:  12
# normalizacao da pagina:  13
# normalizacao da pagina:  14
# normalizacao da pagina:  15
# normalizacao da pagina:  16
# normalizacao da pagina:  17
# normalizacao da pagina:  18
# normalizacao da pagina:  19
# normalizacao da pagina:  20
# normalizacao da pagina:  21
# normalizacao da pagina:  22
# normalizacao da pagina:  23
# normalizacao da pagina:  24
# normalizacao da pagina:  25
# normalizacao da pagina:  26
# normalizacao da pagina:  27
# normalizacao da pagina:  28
# normalizacao da pagina:  29
# normalizacao da pagina:  30
# normalizacao da pagina:  31
# normalizacao da pagina:  32
# normalizacao da pagina:  33
# normalizacao da pagina:  34
# normalizacao da pagina:  35
# normalizacao da pagina:  36
# normalizacao da pagina:  37
# normalizacao da pagina:  38
# normalizacao da pagina:  39
# normalizacao da pagina:  40
# normalizacao da pagina:  41
# normalizacao da pagina:  42
# normalizacao da pagina:  43
# normalizacao da pagina:  44
# normalizacao da pagina:  45
# normalizacao da pagina:  46
# normalizacao da pagina:  47
# normalizacao da pagina:  48
# normalizacao da pagina:  49
# normalizacao da pagina:  50
# normalizacao da pagina:  51
# normalizacao da pagina:  52
# normalizacao da pagina:  53
# normalizacao da pagina:  54
# normalizacao da pagina:  55
# normalizacao da pagina:  56
# normalizacao da pagina:  57
# normalizacao da pagina:  58
# normalizacao da pagina:  59
# normalizacao da pagina:  60
# normalizacao da pagina:  61
# normalizacao da pagina:  62
# normalizacao da pagina:  63
# normalizacao da pagina:  64
# normalizacao da pagina:  65
# normalizacao da pagina:  66
# normalizacao da pagina:  67
# normalizacao da pagina:  68
# normalizacao da pagina:  69
# normalizacao da pagina:  70
# normalizacao da pagina:  71
# normalizacao da pagina:  72
# normalizacao da pagina:  73
# normalizacao da pagina:  74
# normalizacao da pagina:  75
# normalizacao da pagina:  76
# normalizacao da pagina:  77
# normalizacao da pagina:  78
# normalizacao da pagina:  79
# normalizacao da pagina:  80
# normalizacao da pagina:  81
# normalizacao da pagina:  82
# normalizacao da pagina:  83
# normalizacao da pagina:  84
# normalizacao da pagina:  85
# normalizacao da pagina:  86
# normalizacao da pagina:  87
# normalizacao da pagina:  88
# normalizacao da pagina:  89
# normalizacao da pagina:  90
# normalizacao da pagina:  91
# normalizacao da pagina:  92
# normalizacao da pagina:  93
# normalizacao da pagina:  94
# normalizacao da pagina:  95
# normalizacao da pagina:  96
# normalizacao da pagina:  97
# normalizacao da pagina:  98
# normalizacao da pagina:  99
# normalizacao da pagina:  100
# normalizacao da pagina:  101
# normalizacao da pagina:  102
# normalizacao da pagina:  103
# normalizacao da pagina:  104
# normalizacao da pagina:  105
# normalizacao da pagina:  106
# normalizacao da pagina:  107
# normalizacao da pagina:  108
# normalizacao da pagina:  109
# normalizacao da pagina:  110
# normalizacao da pagina:  111
# normalizacao da pagina:  112
# normalizacao da pagina:  113
# normalizacao da pagina:  114
# normalizacao da pagina:  115
# normalizacao da pagina:  116
# normalizacao da pagina:  117
# normalizacao da pagina:  118
# normalizacao da pagina:  119
# normalizacao da pagina:  120
# normalizacao da pagina:  121
# normalizacao da pagina:  122
# normalizacao da pagina:  123
# normalizacao da pagina:  124
# normalizacao da pagina:  125
# normalizacao da pagina:  126
# normalizacao da pagina:  127
# normalizacao da pagina:  128
# normalizacao da pagina:  129
# normalizacao da pagina:  130
# normalizacao da pagina:  131
# normalizacao da pagina:  132
# normalizacao da pagina:  133
# normalizacao da pagina:  134
# normalizacao da pagina:  135
# normalizacao da pagina:  136
# normalizacao da pagina:  137
# normalizacao da pagina:  138
# normalizacao da pagina:  139
# normalizacao da pagina:  140
# normalizacao da pagina:  141
# normalizacao da pagina:  142
# normalizacao da pagina:  143
# normalizacao da pagina:  144
# normalizacao da pagina:  145
# normalizacao da pagina:  146
# normalizacao da pagina:  147
# normalizacao da pagina:  148
# normalizacao da pagina:  149
# normalizacao da pagina:  150
# normalizacao da pagina:  151
# normalizacao da pagina:  152
# normalizacao da pagina:  153
# normalizacao da pagina:  154
# normalizacao da pagina:  155
# normalizacao da pagina:  156
# normalizacao da pagina:  157
# normalizacao da pagina:  158
# normalizacao da pagina:  159
# normalizacao da pagina:  160
# normalizacao da pagina:  161
# normalizacao da pagina:  162
# normalizacao da pagina:  163
# normalizacao da pagina:  164
# normalizacao da pagina:  165
# normalizacao da pagina:  166
# normalizacao da pagina:  167
# normalizacao da pagina:  168
# normalizacao da pagina:  169
# normalizacao da pagina:  170
# normalizacao da pagina:  171
# normalizacao da pagina:  172
# normalizacao da pagina:  173
# normalizacao da pagina:  174
# normalizacao da pagina:  175
# normalizacao da pagina:  176
# normalizacao da pagina:  177
# normalizacao da pagina:  178
# normalizacao da pagina:  179
# normalizacao da pagina:  180
# normalizacao da pagina:  181
# Dados salvos em dados_normalizados.csv!
